# %% [markdown]
# # Lab 2 Insertion Itertools Swap Count

# %%
import random
import itertools
def randomPerm(n):
    v=[]
    for i in range(n):
        v.append(i+1)
    for i in range(len(v)-1):
        j = random.randint(i, len(v)-1)
        aux = v[i]
        v[i] = v[j]
        v[j] = aux
    return v

def isortSteps(a):
    swaps = 0
    v = []
    for i in range(len(a)):
        v.append(a[i])        
    steps = 0
    for i in range(1,len(v)):
        x = v[i]
        j = i-1
        while (j > -1) and (v[j] > x):
            v[j+1] = v[j]
            swaps = swaps + 1
            j = j -1
            steps = steps + 3
        steps = steps + 1
        v[j+1] = x
        swaps = swaps + 1
        steps = steps + 4
    steps = steps + 1
    print 'Swaps: ' + str(swaps)
    return steps

n = 6

sum = 0.0
min = n**3
max = 0.0

x = randomPerm(n)
count = 0
for i in itertools.permutations(x):
    t = isortSteps(i)
    count = count + 1
    if t < min :
       min = t
    if t > max :
       max = t
    sum = sum + t 

print 'n: ' + str(n)
print 'Permutations: ' + str(count)
print 'Theoretical best time, ' + str(5*n - 4) 
print 'Theoretical worst time,' + str((3.0/2.0)*n**2 + (7.0/2.0)*n - 4)
print 'Theoretical average time,' + str((3.0/4.0)*n**2 + (17.0/4.0)*n - 4)
print 'Experimenal best time, ' + str(min)
print 'Experimenal worst time,' + str(max)
print 'Experimenal average time, ' + str(sum/count)
# Out:
# Steps: 2151
# Steps: 2025
# Steps: 2076
# Steps: 1818
# Steps: 1755
# Steps: 2208
# Steps: 2043
# Steps: 2343
# Steps: 1836
# Steps: 1746
# Steps: 1956
# Steps: 2112
# Steps: 1842
# Steps: 1767
# Steps: 1869
# Steps: 1890
# Steps: 1980
# Steps: 2064
# Steps: 2043
# Steps: 2007
# Steps: 2307
# Steps: 2184
# Steps: 2295
# Steps: 1764
# Steps: 1788
# Steps: 1776
# Steps: 2250
# Steps: 2181
# Steps: 2133
# Steps: 2022
# Steps: 2229
# Steps: 1833
# Steps: 2169
# Steps: 2001
# Steps: 1839
# Steps: 2667
# Steps: 2100
# Steps: 1878
# Steps: 2139
# Steps: 2232
# Steps: 1890
# Steps: 2226
# Steps: 2049
# Steps: 1899
# Steps: 2268
# Steps: 2142
# Steps: 2394
# Steps: 2190
# Steps: 2028
# Steps: 2112
# Steps: 2037
# Steps: 2187
# Steps: 1863
# Steps: 1872
# Steps: 2157
# Steps: 2004
# Steps: 2037
# Steps: 2319
# Steps: 2208
# Steps: 2322
# Steps: 1935
# Steps: 2088
# Steps: 2109
# Steps: 1554
# Steps: 2079
# Steps: 1821
# Steps: 2256
# Steps: 1929
# Steps: 2295
# Steps: 2022
# Steps: 2205
# Steps: 2157
# Steps: 1935
# Steps: 1872
# Steps: 1755
# Steps: 1875
# Steps: 2010
# Steps: 2409
# Steps: 2250
# Steps: 1824
# Steps: 2022
# Steps: 2187
# Steps: 2190
# Steps: 1995
# Steps: 2058
# Steps: 2070
# Steps: 2106
# Steps: 2025
# Steps: 1980
# Steps: 2028
# Steps: 2277
# Steps: 2142
# Steps: 2373
# Steps: 2064
# Steps: 1881
# Steps: 1791
# Steps: 2058
# Steps: 1941
# Steps: 2181
# Steps: 2316
# n: 50
# runs: 100
# Theoretical best time, 246
# Theoretical worst time,3921.0
# Theoretical average time,2083.5
# Experimenal best time, 1554
# Experimenal worst time,2667
# Experimenal average time,2055
